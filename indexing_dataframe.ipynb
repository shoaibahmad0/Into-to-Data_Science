# %%
# we use set_index() fucnction for creating a new index
import pandas as pd 

df = pd.read_csv('datasets/Admission_Predict.csv', index_col =0)
df.columns = [x.lower().strip() for x in df.columns]
df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %%
# set it index to its another columns 
df['Serial Numver']=df.index

# now make a new index 

df = df.set_index('cgpa')
df.head()
# Out:
#       gre score  toefl score  university rating  sop  lor  research  \
# cgpa
# 9.65        337          118                  4  4.5  4.5         1
# 8.87        324          107                  4  4.0  4.5         1
# 8.00        316          104                  3  3.0  3.5         1
# 8.67        322          110                  3  3.5  2.5         1
# 8.21        314          103                  2  2.0  3.0         0
#
#       Serial Numver
# cgpa
# 9.65           0.92
# 8.87           0.76
# 8.00           0.72
# 8.67           0.80
# 8.21           0.65

# %%
# we can get rid of the index by calling the function reset_index()

df = df.reset_index()
df.head()
# Out:
#    index  cgpa  gre score  toefl score  university rating  sop  lor  research  \
# 0      0  9.65        337          118                  4  4.5  4.5         1
# 1      1  8.87        324          107                  4  4.0  4.5         1
# 2      2  8.00        316          104                  3  3.0  3.5         1
# 3      3  8.67        322          110                  3  3.5  2.5         1
# 4      4  8.21        314          103                  2  2.0  3.0         0
#
#    Serial Numver
# 0           0.92
# 1           0.76
# 2           0.72
# 3           0.80
# 4           0.65

# %%
# we can create more than one index 
# let's import a new datasets using read_csv() function

new_df = pd.read_csv('datasets/census.csv', index_col = 0)
new_df.columns = [x.lower().strip() for x in new_df.columns]
#new_df.index=[x.lower().strip() for x in new_df.index]
new_df.head()
# Out:
#         region  division  state  county   stname         ctyname  \
# SUMLEV
# 40           3         6      1       0  Alabama         Alabama
# 50           3         6      1       1  Alabama  Autauga County
# 50           3         6      1       3  Alabama  Baldwin County
# 50           3         6      1       5  Alabama  Barbour County
# 50           3         6      1       7  Alabama     Bibb County
#
#         census2010pop  estimatesbase2010  popestimate2010  popestimate2011  \
# SUMLEV
# 40            4779736            4780127          4785161          4801108
# 50              54571              54571            54660            55253
# 50             182265             182265           183193           186659
# 50              27457              27457            27341            27226
# 50              22915              22919            22861            22733
#
#         ...  rdomesticmig2011  rdomesticmig2012  rdomesticmig2013  \
# SUMLEV  ...
# ...

# %%
# we can get unique values using the unique() 
new_df=new_df[new_df['SUMLEV']==50]
