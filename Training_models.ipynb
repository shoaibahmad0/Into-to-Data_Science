# %% [markdown]
# <a href="https://colab.research.google.com/github/shoaibahmad0/Intro-to-Data_Science/blob/main/Training_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams["figure.figsize"] = [10,5]
# ignore warnings

import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
current_palate_1 =sns.color_palette()
sns.palplot(current_palate_1)
plt.show()

# %%
current_palete_2 = sns.color_palette()
sns.palplot(sns.color_palette("Reds"))
plt.show()

# %%
current_palete_2 = sns.color_palette()
sns.palplot(sns.color_palette("colorblind"))
plt.show()

# %%
full_data = pd.read_csv("/content/titanic.csv")

# %%
full_data.shape
# Out:
# (891, 12)

# %%
full_data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
sns.histplot(full_data['Parch'],kde = True)
plt.show()

# %%
sns.distplot(full_data['Age'], hist = True)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.distplot(full_data["Age"])
plt.show()

# %%
sns.relplot(x="Age", y ="Fare", col="Pclass",hue = "Sex", style = "Sex", kind="line", data=full_data)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x="Age",y="Fare",hue="Sex", data = full_data)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.lineplot(x="Age",y="Fare",hue="Sex", style="Sex", data = full_data)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.barplot(x="Age",y="Fare",hue="Sex", data = full_data)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.stripplot(x="Sex",y="Age",hue="Sex", data = full_data)
plt.show()

# %%
sns.violinplot(x="Survived",y="Age",hue="Sex", data = full_data)
plt.show()

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.heatmap(full_data.isnull(), yticklabels=False, cbar = False, cmap="tab20c_r")
plt.title("Missing Data: Training Set")
plt.show()

# %%
#defining a function
def input_age(cols):
    Age = cols[0]
    Pclass = cols[1]


    if pd.isnull(Age):
      if Pclass == 1:
        return 37
      elif Pclass == 2:
        return 29
      else:
        return 24
    else:
      return Age

full_data["Age"]=full_data[['Age','Pclass']].apply(input_age,axis=1)

# %%
full_data.drop("Cabin", axis =1, inplace = True)

# %%
full_data.dropna(inplace=True)

# %%
full_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
full_data.drop(['Name','Ticket'],axis=1,inplace=True)
objcat = ['Sex','Embarked']

# %%
full_data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female  24.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
full_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   889.000000  889.000000  889.000000  889.000000  889.000000
# mean    446.000000    0.382452    2.311586   29.019314    0.524184
# std     256.998173    0.486260    0.834700   13.209814    1.103705
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     224.000000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   26.000000    0.000000
# 75%     668.000000    1.000000    3.000000   36.500000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  889.000000  889.000000
# mean     0.382452   32.096681
# std      0.806761   49.697504
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
full_data.drop('PassengerId', axis=1,inplace=True)

# %%
full_data.shape
# Out:
# (889, 8)

# %%
full_data.select_dtypes(['category']).columns
# Out:
# Index([], dtype='object')

# %%
sex=pd.get_dummies(full_data['Sex'], drop_first = True)
embarked=pd.get_dummies(full_data['Embarked'], drop_first = True)

# %%
full_data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
full_data=pd.concat([full_data, sex, embarked], axis=1)
full_data.head(5)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  male  Q  S
# 0         0       3    male  22.0      1      0   7.2500        S     1  0  1
# 1         1       1  female  38.0      1      0  71.2833        C     0  0  0
# 2         1       3  female  26.0      0      0   7.9250        S     0  0  1
# 3         1       1  female  35.0      1      0  53.1000        S     0  0  1
# 4         0       3    male  35.0      0      0   8.0500        S     1  0  1

# %%
if 'Sex' in full_data.columns and 'Embarked' in full_data.columns:
    # Drop the columns
    full_data.drop(['Sex', 'Embarked'], axis=1, inplace=True)
    print('train data shape : ', full_data.shape)
else:
    print('Columns "Sex" and/or "Embarked" not found in the DataFrame.')
    print('train data shape : ', full_data.shape)
# Out:
# train data shape :  (889, 9)

# %%
x = full_data.drop('Survived', axis = 1)

y = full_data['Survived']

# %%
x = full_data.drop('Survived', axis = 1)
y = full_data['Survived']

# %%
x.shape
# Out:
# (889, 8)

# %%
y.shape
# Out:
# (889,)

# %%
from sklearn import preprocessing
pre_process = preprocessing.StandardScaler().fit(x)
x_transform = pre_process.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = .20, random_state = 101)

# %%
x_train.shape
x_train
# Out:
#      Pclass   Age  SibSp  Parch      Fare  male  Q  S
# 307       1  17.0      1      0  108.9000     0  0  0
# 229       3  24.0      3      1   25.4667     0  0  1
# 82        3  24.0      0      0    7.7875     0  1  0
# 353       3  25.0      1      0   17.8000     1  0  1
# 707       1  42.0      0      0   26.2875     1  0  1
# ..      ...   ...    ...    ...       ...   ... .. ..
# 576       2  34.0      0      0   13.0000     0  0  1
# 840       3  20.0      0      0    7.9250     1  0  1
# 338       3  45.0      0      0    8.0500     1  0  1
# 524       3  24.0      0      0    7.2292     1  0  0
# 865       2  42.0      0      0   13.0000     0  0  1
#
# [711 rows x 8 columns]

# %%
y_train
# Out:
# 307    1
# 229    0
# 82     1
# 353    0
# 707    1
#       ..
# 576    1
# 840    0
# 338    1
# 524    0
# 865    1
# Name: Survived, Length: 711, dtype: int64

# %%
x_test.shape
x_test
# Out:
#      Pclass   Age  SibSp  Parch      Fare  male  Q  S
# 511       3  24.0      0      0    8.0500     1  0  1
# 613       3  24.0      0      0    7.7500     1  1  0
# 615       2  24.0      1      2   65.0000     0  0  1
# 337       1  41.0      0      0  134.5000     0  0  0
# 718       3  24.0      0      0   15.5000     1  1  0
# ..      ...   ...    ...    ...       ...   ... .. ..
# 155       1  51.0      0      1   61.3792     1  0  0
# 450       2  36.0      1      2   27.7500     1  0  1
# 756       3  28.0      0      0    7.7958     1  0  1
# 187       1  45.0      0      0   26.5500     1  0  1
# 180       3  24.0      8      2   69.5500     0  0  1
#
# [178 rows x 8 columns]

# %%
y_test
# Out:
# 511    0
# 613    0
# 615    1
# 337    1
# 718    0
#       ..
# 155    0
# 450    0
# 756    0
# 187    1
# 180    0
# Name: Survived, Length: 178, dtype: int64

# %% [markdown]
# # **MODEL** **TRAINING**

# %%
from sklearn.linear_model import LogisticRegression

print("Logistic Regression ")
log_reg = LogisticRegression()
# now passing training data into model
log_reg.fit(x_train, y_train)
# Out:
# Logistic Regression
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
y_pred_log_reg = log_reg.predict(x_test)
print("Logistic Regression")


print('--'*30)


log_reg_accuracy = round(accuracy_score(y_test,y_pred_log_reg) * 100, 2)
print("ACCURACY = ",log_reg_accuracy,'%')
# Out:
# Logistic Regression
# ------------------------------------------------------------
# ACCURACY =  82.02 %

# %%
from sklearn.tree import DecisionTreeClassifier

print("Decision Tree classifier")

Dtree = DecisionTreeClassifier()

Dtree.fit(x_train,y_train)
# Out:
# Decision Tree classifier
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score

y_pred_dtree = Dtree.predict(x_test)

print("decision tree classifier")
print('--'*30)

dtree_accuracy = round(accuracy_score(y_test,y_pred_dtree) * 100, 2)
print("Accuracy :",dtree_accuracy,"%")
# Out:
# decision tree classifier
# ------------------------------------------------------------
# Accuracy : 79.78 %

# %% [markdown]
# # Random **forest**

# %%
from sklearn.ensemble import RandomForestClassifier
print("RANDOM FOREST CLASSIFIER")

rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RANDOM FOREST CLASSIFIER
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score

y_pred_rfc = rfc.predict(x_test)

print("random forest Classifier")
print('=='*30)

rfc_accuracy = round(accuracy_score(y_test,y_pred_rfc) * 100, 2)
print("accuracy :", rfc_accuracy,"%")
# Out:
# random forest Classifier
# ...
# accuracy : 82.58 %

# %% [markdown]
# GRADIENT BOOSTING CLASSIFIER
# # **bold text**

# %%
from sklearn.ensemble import GradientBoostingClassifier

print("Gradient Boosting Classifier")

gbc = GradientBoostingClassifier()

gbc.fit(x_train,y_train)
# Out:
# Gradient Boosting Classifier
# GradientBoostingClassifier()

# %%
from sklearn.metrics import accuracy_score

y_pred_gbc = gbc.predict(x_test)

print("---"*30)

gbc_accuracy = round(accuracy_score(y_test,y_pred_gbc)* 100,2)
print("accuracy :", gbc_accuracy,"%")
# Out:
# ------------------------------------------------------------------------------------------
# accuracy : 84.27 %

# %%
model_score = {
                "Logistic regression": log_reg_accuracy,
                "Decision tree classifier ": dtree_accuracy,
                "Random Forest classifier": rfc_accuracy,
                "Gradient boosting classifier":gbc_accuracy
}

sorted_score = sorted(model_score.items(),  key=lambda x: x[1], reverse = True)

print("Models Ranking(greater ranking are better)")

for rank, (model_name,score) in enumerate(sorted_score, start=1):
    print(f"(rank). {model_name}: {score}")
# Out:
# Models Ranking(greater ranking are better)
# (rank). Gradient boosting classifier: 84.27
# (rank). Random Forest classifier: 82.58
# (rank). Logistic regression: 82.02
# (rank). Decision tree classifier : 79.78
